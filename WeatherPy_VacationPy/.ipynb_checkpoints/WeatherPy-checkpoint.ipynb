# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# list of dictionaries to make df when done with loop
city_list = []

# variables for print log
set_num = 1
record_num = 1
city_count = 1

print('''Beginning Data Retrieval
-----------------------------''')
#looping through the cities
for i in range(len(cities)):
    # sending API call and getting json
    url = f"http://api.openweathermap.org/data/2.5/weather?q={cities[i]}&units=imperial&appid={weather_api_key}"
    weather_response = requests.get(url)
    weather_response_json = weather_response.json()

    # resetting my variables for the print log
    if not city_count <= 50:
        set_num += 1
        city_count = 0
        record_num = 0
    # using try except to add cities to database
    try: 
        city_lat = weather_response_json['coord']['lat']
        city_lon = weather_response_json['coord']['lon']
        max_temp = weather_response_json["main"]["temp_max"]
        humidity = weather_response_json["main"]["humidity"]
        cloudiness = weather_response_json["clouds"]["all"]
        wind_speed = weather_response_json["wind"]["speed"]
        country = weather_response_json["sys"]["country"]
        date = weather_response_json["dt"]
    
        city_list.append({
            'City': cities[i], 
            'Lat' : city_lat,
            'Lng' : city_lon,
            'Max Temp': max_temp,
            'Humidity' : humidity,
            'Cloudiness' : cloudiness,
            'Wind Speed' : wind_speed,
            'Country' : country,
            'Date' : date
        })
        # printing log
        print(f"Processing Record {record_num} of Set {set_num} | {cities[i]}")
        city_count += 1
        record_num += 1
    except:
        print("City not found. Skipping...")
        pass
print('''-----------------------------
Data Retrieval Complete
-----------------------------''')

temps_df = pd.DataFrame(city_list)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hami
# Processing Record 2 of Set 1 | zarand
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | beyneu
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 9 of Set 1 | huarmey
# Processing Record 10 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 11 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | comodoro rivadavia
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | tuatapere
# Processing Record 18 of Set 1 | cayenne
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | raudeberg
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | margate
# Processing Record 26 of Set 1 | ostrovnoy
# Processing Record 27 of Set 1 | yeppoon
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | indramayu
# Processing Record 32 of Set 1 | klaksvik
# Processing Record 33 of Set 1 | bereda
# Processing Record 34 of Set 1 | flinders
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | merauke
# Processing Record 23 of Set 4 | doha
# Processing Record 24 of Set 4 | prado
# Processing Record 25 of Set 4 | ko samui
# Processing Record 26 of Set 4 | yasothon
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | andenes
# Processing Record 29 of Set 4 | harwich
# Processing Record 30 of Set 4 | coahuayana
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | mezen
# Processing Record 34 of Set 4 | pena
# Processing Record 35 of Set 4 | presidencia roque saenz pena
# Processing Record 36 of Set 4 | luderitz
# City not found. Skipping...
# Processing Record 37 of Set 4 | alyangula
# Processing Record 38 of Set 4 | zhigansk
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | bulandshahr
# Processing Record 41 of Set 4 | aykhal
# Processing Record 42 of Set 4 | caravelas
# Processing Record 43 of Set 4 | canutama
# Processing Record 44 of Set 4 | bolu
# Processing Record 45 of Set 4 | labuhan
# Processing Record 46 of Set 4 | cluses
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | pizarro
# Processing Record 49 of Set 4 | cherskiy
# Processing Record 50 of Set 4 | ambilobe
# Processing Record 0 of Set 5 | puerto carreno
# Processing Record 1 of Set 5 | cockburn town
# Processing Record 2 of Set 5 | qinggang
# Processing Record 3 of Set 5 | waingapu
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | sungaipenuh
# Processing Record 6 of Set 5 | mogwase
# Processing Record 7 of Set 5 | constitucion
# Processing Record 8 of Set 5 | perth
# Processing Record 9 of Set 5 | jumla
# City not found. Skipping...
# Processing Record 10 of Set 5 | necochea
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | buenos aires
# Processing Record 13 of Set 5 | thunder bay
# City not found. Skipping...
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | zaysan
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | dicabisagan
# Processing Record 19 of Set 5 | meulaboh
# Processing Record 20 of Set 5 | padang
# City not found. Skipping...
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | hidalgo
# Processing Record 23 of Set 5 | high rock
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | mecca
# Processing Record 27 of Set 5 | mercedes
# Processing Record 28 of Set 5 | alamogordo
# Processing Record 29 of Set 5 | waynesville
# Processing Record 30 of Set 5 | ahuimanu
# Processing Record 31 of Set 5 | mitu
# Processing Record 32 of Set 5 | barentu
# Processing Record 33 of Set 5 | havre-saint-pierre
# Processing Record 34 of Set 5 | robertson
# Processing Record 35 of Set 5 | merin
# Processing Record 36 of Set 5 | pangnirtung
# City not found. Skipping...
# Processing Record 37 of Set 5 | khasan
# Processing Record 38 of Set 5 | banjar
# Processing Record 39 of Set 5 | najran
# Processing Record 40 of Set 5 | yumen
# Processing Record 41 of Set 5 | san-pedro
# Processing Record 42 of Set 5 | jagdalpur
# Processing Record 43 of Set 5 | la rioja
# Processing Record 44 of Set 5 | kajaani
# City not found. Skipping...
# Processing Record 45 of Set 5 | kroya
# Processing Record 46 of Set 5 | poum
# Processing Record 47 of Set 5 | san quintin
# Processing Record 48 of Set 5 | mporokoso
# Processing Record 49 of Set 5 | eirunepe
# City not found. Skipping...
# Processing Record 50 of Set 5 | san andres
# Processing Record 0 of Set 6 | kenai
# City not found. Skipping...
# Processing Record 1 of Set 6 | martinsville
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | miragoane
# Processing Record 4 of Set 6 | chadiza
# Processing Record 5 of Set 6 | suffolk
# Processing Record 6 of Set 6 | mehamn
# Processing Record 7 of Set 6 | galesong
# Processing Record 8 of Set 6 | pekalongan
# Processing Record 9 of Set 6 | warrnambool
# Processing Record 10 of Set 6 | abu dhabi
# Processing Record 11 of Set 6 | whitehorse
# Processing Record 12 of Set 6 | bangil
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | alice springs
# Processing Record 15 of Set 6 | onguday
# Processing Record 16 of Set 6 | pozo colorado
# Processing Record 17 of Set 6 | gornyy
# Processing Record 18 of Set 6 | bahia blanca
# Processing Record 19 of Set 6 | pochutla
# Processing Record 20 of Set 6 | ulladulla
# Processing Record 21 of Set 6 | yellowknife
# Processing Record 22 of Set 6 | egvekinot
# Processing Record 23 of Set 6 | shaowu
# Processing Record 24 of Set 6 | lata
# Processing Record 25 of Set 6 | rochegda
# Processing Record 26 of Set 6 | lock haven
# Processing Record 27 of Set 6 | puerto escondido
# Processing Record 28 of Set 6 | mumford
# Processing Record 29 of Set 6 | hobyo
# City not found. Skipping...
# Processing Record 30 of Set 6 | ponta do sol
# Processing Record 31 of Set 6 | todos santos
# Processing Record 32 of Set 6 | muli
# Processing Record 33 of Set 6 | mahendranagar
# Processing Record 34 of Set 6 | hilo
# Processing Record 35 of Set 6 | port blair
# Processing Record 36 of Set 6 | zhanakorgan
# Processing Record 37 of Set 6 | antofagasta
# Processing Record 38 of Set 6 | linqiong
# City not found. Skipping...
# Processing Record 39 of Set 6 | raga
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | boshan
# Processing Record 42 of Set 6 | canaries
# Processing Record 43 of Set 6 | gustavo diaz ordaz
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | yuci
# Processing Record 46 of Set 6 | kruisfontein
# City not found. Skipping...
# Processing Record 47 of Set 6 | katherine
# Processing Record 48 of Set 6 | east london
# Processing Record 49 of Set 6 | arraial do cabo
# Processing Record 50 of Set 6 | manzanillo
# Processing Record 0 of Set 7 | pokhara
# Processing Record 1 of Set 7 | te anau
# Processing Record 2 of Set 7 | beloha
# Processing Record 3 of Set 7 | jacksonville beach
# Processing Record 4 of Set 7 | flagstaff
# Processing Record 5 of Set 7 | woodward
# Processing Record 6 of Set 7 | tome
# Processing Record 7 of Set 7 | tiksi
# Processing Record 8 of Set 7 | kokoda
# Processing Record 9 of Set 7 | myitkyina
# Processing Record 10 of Set 7 | gat
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 44 of Set 9 | mount gambier
# Processing Record 45 of Set 9 | hirtshals
# Processing Record 46 of Set 9 | muroto
# Processing Record 47 of Set 9 | dekernes
# Processing Record 48 of Set 9 | pervomaysk
# Processing Record 49 of Set 9 | ak-dovurak
# Processing Record 50 of Set 9 | algiers
# Processing Record 0 of Set 10 | berlevag
# Processing Record 1 of Set 10 | noumea
# Processing Record 2 of Set 10 | rognan
# Processing Record 3 of Set 10 | brae
# City not found. Skipping...
# Processing Record 4 of Set 10 | lavumisa
# Processing Record 5 of Set 10 | igurusi
# City not found. Skipping...
# Processing Record 6 of Set 10 | albury
# Processing Record 7 of Set 10 | igualada
# Processing Record 8 of Set 10 | capitao poco
# Processing Record 9 of Set 10 | rio grande
# City not found. Skipping...
# Processing Record 10 of Set 10 | obregon
# Processing Record 11 of Set 10 | muros
# Processing Record 12 of Set 10 | pitimbu
# Processing Record 13 of Set 10 | sur
# Processing Record 14 of Set 10 | charcas
# Processing Record 15 of Set 10 | orange cove
# Processing Record 16 of Set 10 | fukue
# Processing Record 17 of Set 10 | zarya
# Processing Record 18 of Set 10 | husavik
# Processing Record 19 of Set 10 | morondava
# Processing Record 20 of Set 10 | teguise
# Processing Record 21 of Set 10 | uspenka
# Processing Record 22 of Set 10 | krasnozerskoye
# Processing Record 23 of Set 10 | edendale
# Processing Record 24 of Set 10 | jacksonville
# Processing Record 25 of Set 10 | jabinyanah
# Processing Record 26 of Set 10 | boralday
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | knysna
# Processing Record 29 of Set 10 | zhangjiakou
# Processing Record 30 of Set 10 | quatre cocos
# City not found. Skipping...
# Processing Record 31 of Set 10 | imeni babushkina
# Processing Record 32 of Set 10 | blackwater
# Processing Record 33 of Set 10 | kyren
# City not found. Skipping...
# Processing Record 34 of Set 10 | catumbela
# Processing Record 35 of Set 10 | canillo
# Processing Record 36 of Set 10 | neuquen
# Processing Record 37 of Set 10 | madimba
# Processing Record 38 of Set 10 | puerto colombia
# Processing Record 39 of Set 10 | mayo
# Processing Record 40 of Set 10 | saint-francois
# Processing Record 41 of Set 10 | kondinskoye
# Processing Record 42 of Set 10 | smithers
# Processing Record 43 of Set 10 | am timan
# City not found. Skipping...
# Processing Record 44 of Set 10 | waycross
# Processing Record 45 of Set 10 | kargil
# Processing Record 46 of Set 10 | mount darwin
# Processing Record 47 of Set 10 | whyalla
# Processing Record 48 of Set 10 | alexandria
# Processing Record 49 of Set 10 | san ignacio
# Processing Record 50 of Set 10 | praia
# Processing Record 0 of Set 11 | auki
# Processing Record 1 of Set 11 | san luis
# Processing Record 2 of Set 11 | lovozero
# Processing Record 3 of Set 11 | matara
# Processing Record 4 of Set 11 | pasighat
# Processing Record 5 of Set 11 | cravo norte
# Processing Record 6 of Set 11 | yulara
# Processing Record 7 of Set 11 | inhambane
# Processing Record 8 of Set 11 | sisimiut
# Processing Record 9 of Set 11 | bathsheba
# Processing Record 10 of Set 11 | aklavik
# Processing Record 11 of Set 11 | saint-leu
# Processing Record 12 of Set 11 | gerash
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | kismayo
# Processing Record 15 of Set 11 | beringovskiy
# Processing Record 16 of Set 11 | arlit
# Processing Record 17 of Set 11 | alvarado
# Processing Record 18 of Set 11 | puerto madryn
# Processing Record 19 of Set 11 | samarai
# Processing Record 20 of Set 11 | weymouth
# Processing Record 21 of Set 11 | irara
# Processing Record 22 of Set 11 | popondetta
# Processing Record 23 of Set 11 | atambua
# Processing Record 24 of Set 11 | manggar
# Processing Record 25 of Set 11 | markala
# Processing Record 26 of Set 11 | kadoma
# Processing Record 27 of Set 11 | sulangan
# Processing Record 28 of Set 11 | kalmunai
# Processing Record 29 of Set 11 | nuuk
# Processing Record 30 of Set 11 | aksarka
# Processing Record 31 of Set 11 | kuvandyk
# Processing Record 32 of Set 11 | les cayes
# Processing Record 33 of Set 11 | guye
# Processing Record 34 of Set 11 | mglin
# Processing Record 35 of Set 11 | chapais
# Processing Record 36 of Set 11 | yibin
# Processing Record 37 of Set 11 | zvishavane
# Processing Record 38 of Set 11 | tallahassee
# Processing Record 39 of Set 11 | visakhapatnam
# Processing Record 40 of Set 11 | umm lajj
# Processing Record 41 of Set 11 | coromandel
# Processing Record 42 of Set 11 | saint-pierre
# Processing Record 43 of Set 11 | ambulu
# Processing Record 44 of Set 11 | port macquarie
# Processing Record 45 of Set 11 | preston
# Processing Record 46 of Set 11 | hearst
# Processing Record 47 of Set 11 | sinnamary
# Processing Record 48 of Set 11 | bud
# Processing Record 49 of Set 11 | dayong
# Processing Record 50 of Set 11 | tuka
# Processing Record 0 of Set 12 | soroca
# Processing Record 1 of Set 12 | piripiri
# Processing Record 2 of Set 12 | pimenteiras
# Processing Record 3 of Set 12 | campo maior
# Processing Record 4 of Set 12 | salinopolis
# City not found. Skipping...
# Processing Record 5 of Set 12 | matane
# Processing Record 6 of Set 12 | singaraja
# Processing Record 7 of Set 12 | verkhoyansk
# Processing Record 8 of Set 12 | chicama
# Processing Record 9 of Set 12 | palencia
# Processing Record 10 of Set 12 | tskaltubo
# Processing Record 11 of Set 12 | kargasok
# Processing Record 12 of Set 12 | powell river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# exporting data into csv and displaying dataframe
temps_df.to_csv('../output_data/weather_export.csv', index=False)
temps_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            hami  42.80   93.45     12.79        71           0        5.97
# 1          zarand  30.81   56.56     35.83        82           0        1.39
# 2         mataura -46.19  168.86     60.01        70          82       10.00
# 3          beyneu  45.32   55.20     22.71        95           0       12.59
# 4          dikson  73.51   80.55     -3.84        92         100       14.52
# ..            ...    ...     ...       ...       ...         ...         ...
# 568       chicama  -7.84  -79.15     69.46        75          89        7.36
# 569      palencia  42.42   -4.50     46.99        89          93        3.00
# 570     tskaltubo  42.33   42.60     50.00        46           0       25.28
# 571      kargasok  59.06   80.86      9.32        95         100        8.46
# 572  powell river  49.85 -124.54     39.20       100          90        5.82
#
#     Country        Date
# 0        CN  1607912099
# 1        IR  1607912099
# 2        NZ  1607911700
# 3        KZ  1607911768
# 4        RU  1607911748
# ..      ...         ...
# 568      PE  1607912201
# 569      ES  1607912201
# 570      GE  1607912201
# 571      RU  1607912201
# 572      CA  1607912106
#
# [573 rows x 9 columns]

# %%
# looking at the summary of the data
temps_summary = temps_df.describe()
temps_summary
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  573.000000
# mean    18.727208   18.220227   52.362565   75.294939   56.577661    7.990803
# std     33.832418   89.624362   29.079601   19.305112   40.706819    6.433588
# min    -54.800000 -179.170000  -52.920000    1.000000    0.000000    0.250000
# 25%     -8.470000  -64.260000   34.390000   67.000000    7.000000    3.360000
# 50%     22.290000   24.930000   61.000000   80.000000   75.000000    5.860000
# 75%     46.430000   96.170000   75.400000   90.000000   99.000000   10.330000
# max     78.220000  179.320000   93.990000  100.000000  100.000000   46.190000
#
#                Date
# count  5.730000e+02
# mean   1.607912e+09
# std    2.120261e+02
# min    1.607911e+09
# 25%    1.607912e+09
# 50%    1.607912e+09
# 75%    1.607912e+09
# max    1.607912e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# no cities have a humidity greater than 100, skipped this

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp_plot = temps_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, alpha=.5, edgecolors='navy')
lat_temp_plot.set_ylabel("Max Temperature (F)")
lat_temp_plot.set_xlabel("Latitude")
plt.title("City Latitude vs. Max Temperature (12/13/20)")
plt.savefig("../output_data/LatitudeMaxTempScatter.png")

# %%
print('''This scatter plot is showing the max temp of a given city on 12/13/2020 by it's latitude coordinate.
The plot demonstrates higher temperatures in the mid to lower latitudes.''')
# Out:
# This scatter plot is showing the max temp of a given city on 12/13/2020 by it's latitude coordinate.
# The plot demonstrates higher temperatures in the mid to lower latitudes.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_hum_plot = temps_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, alpha=.5, edgecolors='navy')
lat_hum_plot.set_ylabel("Humidity (%)")
lat_hum_plot.set_xlabel("Latitude")
plt.title("City Latitude vs. Humidity (12/13/20)")
plt.savefig("../output_data/LatitudeHumidityScatter.png")

# %%
print('''This scatter plot is showing the humidity of a given city on 12/13/2020 by it's latitude coordinate.
This plot showcases that humidity is not well correlated with latitude.''')
# Out:
# This scatter plot is showing the humidity of a given city on 12/13/2020 by it's latitude coordinate.
# This plot showcases that humidity is not well correlated with latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloud_plot = temps_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, alpha=.5, edgecolors='navy')
lat_cloud_plot.set_ylabel("Cloudiness (%)")
lat_cloud_plot.set_xlabel("Latitude")
plt.title("City Latitude vs. Cloudiness (12/13/20)")
plt.savefig("../output_data/LatitudeCloudinessScatter.png")

# %%
print('''This scatter plot is showing the cloudiness of a given city on 12/13/2020 by it's latitude coordinate.
The plot shows the cloudiness for the given day but does not indicate any correlation between latitude and cloudiness.''')
# Out:
# This scatter plot is showing the cloudiness of a given city on 12/13/2020 by it's latitude coordinate.
# The plot shows the cloudiness for the given day but does not indicate any correlation between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_wind_plot = temps_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, alpha=.5, edgecolors='navy')
lat_wind_plot.set_ylabel("Wind Speed (mph)")
lat_wind_plot.set_xlabel("Latitude")
plt.title("City Latitude vs. Wind Speed (12/13/20)")
plt.savefig("../output_data/LatitudeWindSpeedScatter.png")

# %%
print('''This scatter plot is showing the wind speed of a given city on 12/13/2020 by it's latitude coordinate.
There appears to be an increase in wind speed further from the equator but it is a weak correlation.''')
# Out:
# This scatter plot is showing the wind speed of a given city on 12/13/2020 by it's latitude coordinate.
# There appears to be an increase in wind speed further from the equator but it is a weak correlation.

# %% [markdown]
# ## Linear Regression

# %%
# creating a new column to filter by for northern vs southern hemisphere dfs for graphs and linear regressions
temps_df['Hemisphere'] = ["Northern" if x > 0  else "Southern" for x in temps_df['Lat']]
# creating a df for northern hem
north_temps_df = temps_df[temps_df["Hemisphere"] == "Northern"]
#creating a df for southern hem
south_temps_df = temps_df[temps_df["Hemisphere"] == "Southern"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_lat_temp_plot = north_temps_df.plot(kind="scatter", x="Lat", y="Max Temp")
north_lat_temp_plot.set_xlabel("Latitude")
plt.title("Northern Hemisphere - City Latitude vs. Max Temperature (12/13/20)")

x_values = north_temps_df['Lat']
y_values = north_temps_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/NorthernLatitudeMaxTemp.png")
# Out:
# The r-squared is: 0.6615873428510264

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_lat_temp_plot = south_temps_df.plot(kind="scatter", x="Lat", y="Max Temp")
south_lat_temp_plot.set_xlabel("Latitude")
plt.title("Southern Hemisphere - City Latitude vs. Max Temperature (12/13/20)")

x_values = south_temps_df['Lat']
y_values = south_temps_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/SouthernLatitudeMaxTemp.png")
# Out:
# The r-squared is: 0.2872040273132787

# %%
print('''The linear regression for the Northern Hemisphere shows a clear trend of the maximum temperature decreasing
as the latitude moves upwards, away from the equator. The Southern Hemisphere linear regression has an opposite,
but weaker, trend of the maximum temperature decreasing as the latitude moves away from the equator.
Both linear regressions support that the maximum temperatures increase the closer to 0 latitude, or the equator''')
# Out:
# The linear regression for the Northern Hemisphere shows a clear trend of the maximum temperature decreasing
# as the latitude moves upwards, away from the equator. The Southern Hemisphere linear regression has an opposite,
# but weaker, trend of the maximum temperature decreasing as the latitude moves away from the equator.
# Both linear regressions support that the maximum temperatures increase the closer to 0 latitude, or the equator

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_lat_temp_plot = north_temps_df.plot(kind="scatter", x="Lat", y="Humidity")
north_lat_temp_plot.set_xlabel("Latitude")
plt.title("Northern Hemisphere - City Latitude vs. Humidity (12/13/20)")

x_values = north_temps_df['Lat']
y_values = north_temps_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/NorthernLatitudeHumidity.png")
# Out:
# The r-squared is: 0.0871190674445481

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_lat_temp_plot = south_temps_df.plot(kind="scatter", x="Lat", y="Humidity")
south_lat_temp_plot.set_xlabel("Latitude")
plt.title("Southern Hemisphere - City Latitude vs. Humidity (12/13/20)")

x_values = south_temps_df['Lat']
y_values = south_temps_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/SouthernLatitudeHumidity.png")
# Out:
# The r-squared is: 0.1222630847795331

# %%
print('''The trend lines of the linear regression for the Northern Hemisphere and Southern Hemisphere
appear to show that the higher the latitude the higher the humidity level. However, the r-squared 
values for both linear regressions are so low that we cannot make any meanful conclusions from this dataset.''')
# Out:
# The trend lines of the linear regression for the Northern Hemisphere and Southern Hemisphere
# appear to show that the higher the latitude the higher the humidity level. However, the r-squared
# values for both linear regressions are so low that we cannot make any meanful conclusions from this dataset.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_lat_temp_plot = north_temps_df.plot(kind="scatter", x="Lat", y="Cloudiness")
north_lat_temp_plot.set_xlabel("Latitude")
plt.title("Northern Hemisphere - City Latitude vs. Cloudiness (12/13/20)")

x_values = north_temps_df['Lat']
y_values = north_temps_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,5),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/NorthernLatitudeCloudiness.png")
# Out:
# The r-squared is: 0.12070129351917025

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_lat_temp_plot = south_temps_df.plot(kind="scatter", x="Lat", y="Cloudiness")
south_lat_temp_plot.set_xlabel("Latitude")
plt.title("Southern Hemisphere - City Latitude vs. Cloudiness (12/13/20)")

x_values = south_temps_df['Lat']
y_values = south_temps_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/SouthernLatitudeCloudiness.png")
# Out:
# The r-squared is: 0.1353193954249023

# %%
print('''The scatter plots shows the data is clustered around the extremes. The r-squared value is so low on both
the Southern and Northern Hemisphere plots showing cloudiness that no meaningful conclusions can be drawn from this data''')
# Out:
# The scatter plots shows the data is clustered around the extremes. The r-squared value is so low on both
# the Southern and Northern Hemisphere plots showing cloudiness that no meaningful conclusions can be drawn from this data

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_lat_temp_plot = north_temps_df.plot(kind="scatter", x="Lat", y="Wind Speed")
north_lat_temp_plot.set_xlabel("Latitude")
plt.title("Northern Hemisphere - City Latitude vs. Wind Speed (12/13/20)")

x_values = north_temps_df['Lat']
y_values = north_temps_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,40),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/NorthernLatitudeWindSpeed.png")
# Out:
# The r-squared is: 0.06626869072014593

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_lat_temp_plot = south_temps_df.plot(kind="scatter", x="Lat", y="Wind Speed")
south_lat_temp_plot.set_xlabel("Latitude")
plt.title("Southern Hemisphere - City Latitude vs. Wind Speed (12/13/20)")

x_values = south_temps_df['Lat']
y_values = south_temps_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,23),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/SouthernLatitudeWindSpeed.png")
# Out:
# The r-squared is: 0.08897246327817802

# %%
print('''The Northern Hemisphere has higher max wind speeds than the Southern Hemisphere. Similar to the linear
regressions on cloudiness and latitude, the r-squared values for both the Southern and Northern Hemispheres'
are too low for any meaningful conclusions to be drawn from this data.''')
# Out:
# The Northern Hemisphere has higher max wind speeds than the Southern Hemisphere. Similar to the linear
# regressions on cloudiness and latitude, the r-squared values for both the Southern and Northern Hemispheres'
# are too low for any meaningful conclusions to be drawn from this data.
